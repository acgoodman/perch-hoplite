# %%
#@title Imports
from IPython.display import display
import ipywidgets as widgets
import numpy as np
from etils import epath

from perch_hoplite.agile import colab_utils
from perch_hoplite.agile import embed
from perch_hoplite.agile import source_info
from perch_hoplite.db import interface
from perch_hoplite.db import brutalism
# Out:
# 2025-05-13 16:10:24.725472: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-05-13 16:10:24.725518: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-05-13 16:10:24.732886: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-13 16:10:24.750025: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-05-13 16:10:25.480104: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Embed

# %%
#@title Configuration { vertical-output: true }

#@markdown Configure the raw dataset location(s).  The format is a mapping from
#@markdown a dataset_name to a (base_path, fileglob) pair.  Note that the file
#@markdown globs are case sensitive.  The dataset name can be anything you want.
#
#@markdown This structure allows you to move your data around without having to
#@markdown re-embed the dataset.  The generated embedding database will be
#@markdown placed in the base path. This allows you to simply swap out
#@markdown the base path here if you ever move your dataset.

#@markdown By default we only process one dataset at a time.  Re-run this entire notebook
#@markdown once per dataset.  The embeddings database will be located in the
#@markdown database_base_path.

#@markdown For example, we might set dataset_base_path to '/home/me/myproject',
#@markdown and use the glob '*/*.wav' if all of the audio files have filepaths
#@markdown like '/home/me/myproject/site_XYZ/audio_ABC.wav'
dataset_name = 'INCT17'  #@param {type:'string'}
dataset_base_path = '/home/Goodman/data/INCT17'  #@param {type:'string'}
dataset_fileglob = '*.wav'  #@param {type:'string'}
#@markdown You do not need to change this unless you want to maintain multiple
#@markdown distinct embedding databases.
db_path = None #@param

#@markdown Choose a supported model: `perch_8` or `birdnet_v2.3` are most common
#@markdown for birds. Other choices include `surfperch` for coral reefs or
#@markdown `multispecies_whale` for marine mammals.
model_choice = 'perch_8'  #@param['perch_8', 'humpback', 'multispecies_whale', 'surfperch', 'birdnet_V2.3']

#@markdown File sharding automatically splits audio files into one-minute chunks
#@markdown for embedding. This limits both system and GPU memory usage,
#@markdown especially useful when working with long files (>1 hour).
use_file_sharding = True  #@param {type:'boolean'}

audio_glob = source_info.AudioSourceConfig(
    dataset_name=dataset_name,
    base_path=dataset_base_path,
    file_glob=dataset_fileglob,
    min_audio_len_s=1.0,
    target_sample_rate_hz=-2,
    shard_len_s=60.0 if use_file_sharding else None,
)

configs = colab_utils.load_configs(
    source_info.AudioSources((audio_glob,)),
    db_path,
    model_config_key=model_choice,
    db_key = 'sqlite_usearch')
configs
# Out:
# AgileConfigs(audio_sources_config=AudioSources(audio_globs=(AudioSourceConfig(dataset_name='INCT17', base_path='/home/Goodman/data/INCT17', file_glob='*.wav', min_audio_len_s=1.0, target_sample_rate_hz=-2, shard_len_s=60.0, max_shards_per_file=None),)), db_config=DBConfig(db_key='sqlite_usearch', db_config=db_path: !!python/object/apply:etils.epath.gpath.PosixGPath
# - /
# - home
# - Goodman
# - data
# - INCT17
# usearch_cfg:
#   dtype: float16
#   embedding_dim: 1280
#   expansion_add: 256
#   expansion_search: 128
#   metric_name: IP
# ), model_config=ModelConfig(model_key='taxonomy_model_tf', embedding_dim=1280, model_config=hop_size_s: 5.0
# model_path: ''
# sample_rate: 32000
# tfhub_version: 8
# window_size_s: 5.0
# ))

# %%
#@title Initialize the DB { vertical-output: true }
global db
db = configs.db_config.load_db()
num_embeddings = db.count_embeddings()

print('Initialized DB located at ', configs.db_config.db_config.db_path)

def drop_and_reload_db(_) -> interface.HopliteDBInterface:
  db_path = epath.Path(configs.db_config.db_config.db_path)
  for fp in db_path.glob('hoplite.sqlite*'):
    fp.unlink()
  (db_path / 'usearch.index').unlink()
  print('\n Deleted previous db at: ', configs.db_config.db_config.db_path)
  db = configs.db_config.load_db()

drop_existing_db = True  #@param[True, False]

if num_embeddings > 0 and drop_existing_db:
  print('Existing DB contains datasets: ', db.get_dataset_names())
  print('num embeddings: ', num_embeddings)
  print('\n\nClick the button below to confirm you really want to drop the database at ')
  print(f'{configs.db_config.db_config.db_path}\n')
  print(f'This will permanently delete all {num_embeddings} embeddings from the existing database.\n')
  print('If you do NOT want to delete this data, set `drop_existing_db` above to `False` and re-run this cell.\n')

  button = widgets.Button(description='Delete database?')
  button.on_click(drop_and_reload_db)
  display(button)
# Out:
# Initialized DB located at  /home/Goodman/data/INCT17

# %%
#@title Run the embedding { vertical-output: true }

print(f'Embedding dataset: {audio_glob.dataset_name}')

worker = embed.EmbedWorker(
    audio_sources=configs.audio_sources_config,
    db=db,
    model_config=configs.model_config)

worker.process_all(target_dataset_name=audio_glob.dataset_name)

print('\n\nEmbedding complete, total embeddings: ', db.count_embeddings())
# Out:
# Embedding dataset: INCT17
# 2025-05-13 16:10:26.546436: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-13 16:10:26.591160: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-13 16:10:26.591407: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-13 16:10:26.593159: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-13 16:10:26.593346: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-13 16:10:26.593502: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-13 16:10:26.739921: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-13 16:10:26.740121: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-13 16:10:26.740292: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:901] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-05-13 16:10:26.740414: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5579 MB memory:  -> device: 0, name: GRID A100X-8C, pci bus id: 0000:04:00.0, compute capability: 8.0
#   0%|          | 0/20532 [00:00<?, ?it/s]WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200309_171500_43_46.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
#   0%|          | 1/20532 [00:01<7:30:17,  1.32s/it]WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201123_003000_25_28.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200113_193000_25_28.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201114_191500_8_11.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200209_183000_41_44.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200203_003000_44_47.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200123_211500_40_43.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200111_021500_37_40.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201128_030000_55_58.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191217_213000_46_49.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191220_020000_12_15.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191217_233000_57_60.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200131_210000_54_57.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191217_233000_29_32.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200317_043000_15_18.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200111_201500_11_14.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200111_201500_21_24.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191217_183000_56_59.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201123_010000_49_52.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201114_181500_13_16.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200323_001500_29_32.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200317_174500_27_30.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
#   0%|          | 22/20532 [00:01<16:05, 21.25it/s] WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201128_170000_2_5.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200128_174500_0_3.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200120_040000_8_11.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200331_180000_36_39.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200211_041500_23_26.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200107_030000_32_35.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201126_040000_53_56.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200311_231500_34_37.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200111_001500_45_48.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200210_003000_55_58.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201128_020000_5_8.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200208_174500_45_48.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200113_003000_3_6.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200128_174500_27_30.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200201_001500_24_27.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200307_190000_17_20.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201128_180000_3_6.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200131_220000_48_51.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201128_190000_13_16.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200131_220000_12_15.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191227_231500_21_24.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201112_040000_26_29.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
#   0%|          | 44/20532 [00:01<07:29, 45.55it/s]WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200113_193000_53_56.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201127_220000_35_38.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200107_230000_54_57.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191222_004500_18_21.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191218_220000_3_6.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200113
42_45.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# 100%|█████████▉| 20450/20532 [01:34<00:00, 217.69it/s]WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200131_220000_41_44.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200201_031500_41_44.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201127_220000_1_4.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200229_201500_26_29.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200313_033000_28_31.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200320_193000_10_13.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200111_231500_32_35.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191217_213000_43_46.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200111_021500_13_16.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191215_234500_28_31.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200113_023000_0_3.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191216_001500_55_58.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191227_013000_12_15.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200202_193000_17_20.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200128_040000_45_48.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191221_174500_12_15.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201122_023000_5_8.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201123_203000_42_45.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200203_033000_47_50.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191222_021500_9_12.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200128_174500_48_51.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200319_174500_24_27.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# 100%|█████████▉| 20472/20532 [01:34<00:00, 216.57it/s]WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200319_174500_2_5.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191216_001500_20_23.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191227_231500_45_48.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191217_010000_22_25.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201129_000000_39_42.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200229_201500_0_3.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200323_201500_51_54.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191222_004500_11_14.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191222_004500_0_3.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200320_223000_38_41.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200201_021500_55_58.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201109_020000_1_4.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191228_031500_52_55.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201114_171500_47_50.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200120_213000_4_7.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200123_211500_22_25.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200115_040000_30_33.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200203_033000_10_13.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200123_011500_54_57.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191113_040000_39_42.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191221_174500_25_28.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200119_040000_6_9.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# 100%|█████████▉| 20494/20532 [01:34<00:00, 216.30it/s]WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200212_201500_36_39.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191217_010000_50_53.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200226_020000_40_43.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191223_033000_21_24.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200307_230000_35_38.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201128_200000_36_39.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200107_180000_13_16.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201128_230000_47_50.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201114_221500_53_56.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191227_221500_38_41.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200311_031500_56_59.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200313_013000_8_11.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201123_003000_54_57.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200202_213000_31_34.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200307_020000_20_23.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200120_174500_11_14.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200131_000000_49_52.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201128_220000_31_34.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191217_213000_1_4.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191218_190000_5_8.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200331_180000_5_8.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200212_191500_37_40.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200219_020000_44_47.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# 100%|█████████▉| 20517/20532 [01:34<00:00, 217.99it/s]WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201123_213000_55_58.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200131_010000_25_28.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200131_220000_44_47.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201128_220000_9_12.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191207_031500_49_52.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191222_201500_16_19.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200331_190000_30_33.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200225_230000_56_59.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200219_030000_34_37.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201113_021500_51_54.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20191223_033000_33_36.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201128_180000_47_50.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20201127_180000_46_49.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200203_023000_2_5.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# WARNING:absl:The audio at (/home/Goodman/data/INCT17/INCT17_20200209_174500_20_23.wav / 0.000000) could not be loaded (embeddings already exist). The exception was (no_exception)
# 100%|██████████| 20532/20532 [01:34<00:00, 216.16it/s]
# Embedding complete, total embeddings:  0

# %%
#@title Per dataset statistics { vertical-output: true }

for dataset in db.get_dataset_names():
  print(f'\nDataset \'{dataset}\':')
  print('\tnum embeddings: ', db.get_embeddings_by_source(dataset, source_id=None).shape[0])
# Out:
# Dataset 'INCT17':
# 	num embeddings:  20532
#
# Dataset 'INCT17_20191113_040000_0_3.wav':
# 	num embeddings:  20532

# %%
#@title Show example embedding

q = db.get_embedding(db.get_one_embedding_id())
# %time results, scores = brutalism.brute_search(worker.db, query_embedding=q, search_list_size=128, score_fn=np.dot)
print([int(r.embedding_id) for r in results])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 #@title Show example embedding
# ----> 3 q = db.get_embedding(db.get_one_embedding_id())
#       4 get_ipython().run_line_magic('time', 'results, scores = brutalism.brute_search(worker.db, query_embedding=q, search_list_size=128, score_fn=np.dot)')
#       5 print([int(r.embedding_id) for r in results])
#
# File ~/miniforge3/envs/hoplite/lib/python3.10/site-packages/perch_hoplite/db/sqlite_usearch_impl.py:280, in SQLiteUsearchDB.get_embedding(self, embedding_id)
#     278 contains = self.ui.contains(embedding_id)
#     279 if not np.all(contains):
# --> 280   raise ValueError(f'Embeddings {embedding_id} not found.')
#     281 emb = self.ui.get(embedding_id)
#     282 return np.array(emb)
#
# ValueError: Embeddings 1 not found.
